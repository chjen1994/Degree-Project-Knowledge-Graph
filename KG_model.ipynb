# %%
import spacy as spacy
#check https://towardsdatascience.com/auto-generated-knowledge-graphs-92ca99a81121
from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy import displacy
import re
import os.path
my_path = os.path.abspath('')

# %%
#read all the text file in the directory
def file_reader(path):
    files = []
    for r,d,f in os.walk(path):
        for file in f:
            if '.txt' in file:
                files.append(os.path.join(r,file))       
    return files

#print elements from list
def print_list(lists):
    for list in lists:
        print(list)

# %%
#get competitor triples 
def get_num_of_company_competitor_ent(doc):
    relations = list()
    num_ent_competitor=0

    for sent in doc.sents:
        check=0
        for token in sent:
            if token.lemma_ =="competitor" or token.lemma_ =="compete" or token.lemma_ =="competition":
                if check==0: 
                    for ent in sent.ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            num_ent_competitor=num_ent_competitor+1
                check=check+1
            
    return num_ent_competitor
def get_competitor_triples(triples, doc):
 
    for sent in doc.sents:
        #get relations
        relations = list()
        ents=list()
        head=list()
        tail=list()
        check=True
        has_other_relation=False
        for i, token in enumerate(sent):
            if token.lemma_ =="competitor" or token.lemma_ =="compete" or token.lemma_ =="competition" and len(sent.ents)>1:
                relations.append(token.text)
                if check==True:
                    for ent in sent[:i].ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            if ent.text not in head and ent.text not in tail:
                                head.append([ent.text,ent.label_])
                    for ent in sent[i:].ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            if ent.text not in tail and ent.text not in head:
                                tail.append([ent.text,ent.label_])
                    check= False
                    if len(head)==0 and len(tail)>1:
                        head.append(tail[0])
                        tail.pop(0)
                    #if len(head)>1 and len(tail)==0:
                    
                    
        #if len(relations)>0 and len(head)>0 and len(tail)>0:

            #print(head )
            #print(relations)
            #print(tail)
            #print()
        #form triples  
        if len(relations)>0 and len(head)>0 and len(tail)>0:
            for h in head:
                for t in tail:
                    triples.append([h, relations[0], t])
    #print(triples)
    return triples

# %%
#products
def get_num_of_company_product_ent(doc):
    
    relations = list()
    num_ent_product=0
    has_other_relation=False

    for sent in doc.sents:
        check=0
        for token in sent:
            if token.lemma_ =="competitor" or token.lemma_ =="compete" or token.lemma_ =="competition" or token.lemma_=="client" or token.lemma_=="manufacturer" or token.lemma_=="customer" or token.lemma_=="buyer" or token.lemma_=="purchase" or token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
                has_other_relation=True
            if has_other_relation==False:
                if token.lemma_ =="product" or token.lemma_ =="service" or token.lemma_ =="sell" or token.lemma_=="device" or token.lemma_=="provide" or token.lemma_=="offer" or token.lemma_=="develop" or token.lemma_=="design" or token.lemma_=="solutions"or token.lemma_ =="manufacture" or token.lemma_ =="tool":
                    if check==0: 
                        for ent in sent.ents:
                            if ent.label_=='ORG' or ent.label_=='PRODUCT':
                                num_ent_product=num_ent_product+1
                    check=check+1
            
    return num_ent_product
def get_product_tuples(triples, doc):

    for sent in doc.sents:
        #get relations
        relations = list()
        ents=list()
        head=list()
        tail=list()
        check=True
        has_other_relation=False
        for token in sent:
            if token.lemma_ =="competitor" or token.lemma_ =="compete" or token.lemma_ =="competition" or token.lemma_=="client" or token.lemma_=="manufacturer" or token.lemma_=="customer" or token.lemma_=="buyer" or token.lemma_=="purchase" or token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
                has_other_relation=True
        if has_other_relation==False:
            for i, token in enumerate(sent):
                if token.lemma_ =="product" or token.lemma_ =="service" or token.lemma_ =="sell" or token.lemma_=="device" or token.lemma_=="provide" or token.lemma_=="offer" or token.lemma_=="develop" or token.lemma_=="design" or token.lemma_=="solutions"or token.lemma_ =="manufacture" or token.lemma_ =="tool":
                    relations.append(token.text)
                    if check==True:
                        for ent in sent[:i].ents:
                            if ent.label_=='ORG' or ent.label_=='PRODUCT':
                                if ent.text not in head and ent.text not in tail:
                                    head.append([ent.text,ent.label_])
                        for ent in sent[i:].ents:
                            if ent.label_=='ORG' or ent.label_=='PRODUCT':
                                if ent.text not in tail and ent.text not in head:
                                    tail.append([ent.text,ent.label_])
                        check= False
                    if len(head)==0 and len(tail)>1:
                        head.append(tail[0])
                        tail.pop(0)
        if len(relations)>0  and len(head)>0 and len(tail)>0:

        #print(head )
        #print(relations)
        #print(tail)
        #print()
            for h in head:
                for t in tail:
                    triples.append([h, relations[0], t])
    #print(triples)
    return triples

# %%
#aquisition

#acquisition triples
#products
def get_num_of_company_aquisition_ent(doc):
    
    relations = list()
    num_ent_product=0

    for sent in doc.sents:
        check=0
        for token in sent:
            if token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
                if check==0: 
                    for ent in sent.ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            num_ent_product=num_ent_product+1
                check=check+1
            
    return num_ent_product

def get_aquisition_tuples(triples, doc):
    for sent in doc.sents:
    #get relations
        relations = list()
        ents=list()
        head=list()
        tail=list()
        check=True
      
        for i, token in enumerate(sent):
            if token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
                relations.append(token.text)
                if check==True:
                    for ent in sent[:i].ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            if ent.text not in head and ent.text not in tail:
                                head.append([ent.text,ent.label_])
                    for ent in sent[i:].ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            if ent.text not in tail and ent.text not in head:
                                tail.append([ent.text,ent.label_])
                    check= False
                    if len(head)==0 and len(tail)>1:
                        head.append(tail[0])
                        tail.pop(0)
                    #if len(head)>1 and len(tail)==0:
        if len(relations)>0  and len(head)>0 and len(tail)>0:

        #print(head )
        #print(relations)
        #print(tail)
        #print()
            for h in head:
                for t in tail:
                    triples.append([h, relations[0], t])
    
    #print(triples)


    return triples

# %%
import time
start_time = time.time()

# %%
nlp = spacy.load('en_core_web_lg')

# %%
files = file_reader(my_path+"/clean_data/item1_business")
files.sort()
print_list(files)
#file = my_path+"/micosoft.txt"
# Out:
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/ACIW_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/ADS_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/AKAM_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/ALRM_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/AMZN_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/BCOR_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/BKI_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CARG_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CARS_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_10.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_11.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_12.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_13.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_14.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_15.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_16.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_17.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CI_section_18.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CONE_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/CTXS_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/DBX_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/DOCU_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/DT_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/EBIX_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/EQIX_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/EVOP_section_4.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/EVTC_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FB_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FDX_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FEYE_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FFIV_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FICO_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FISV_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FIS_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FLT_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FLWS_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/FTNT_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/GDDY_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/GDOT_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/GOOG_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/GPN_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/GWRE_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/IAA_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/IAC_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/IDCC_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/JCOM_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/JNPR_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/MA_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/MELI_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/MIME_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/MTCH_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/NEWR_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/NFLX_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/NLOK_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/NTAP_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/NTCT_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/OSTK_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/PANW_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/PBI_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/PFPT_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/PINS_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/PSN_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/PYPL_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/QLYS_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/QNST_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/QTS_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/QTWO_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/QUOT_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/REAL_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/ROP_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/SFIX_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/SQ_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/SSNC_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/SWCH_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/SWI_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/TENB_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/TRIP_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/TWTR_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_4.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_5.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_6.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_7.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_8.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/UPS_section_9.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/VMW_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/V_section_2.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/WSM_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/W_section_3.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/YELP_section_1.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/ZS_section_0.txt
# /Users/davidren/Desktop/Education/KTH/2019-2020/2020 Spring/Master Thesis/Data/clean_data/item1_business/Z_section_1.txt

# %%
competitor_triples=list()
product_triples=list()
aquisition_triples=list()
num_aquisition_ent=0
num_of_company_product_ent=0
num_of_company_competitor_ent=0
for file in files:
    text=open(file)
    doc = nlp(text.read())
    num_of_company_competitor_ent=num_of_company_competitor_ent+get_num_of_company_competitor_ent(doc)
    num_of_company_product_ent=num_of_company_product_ent+get_num_of_company_product_ent(doc)
    num_aquisition_ent=num_aquisition_ent+get_num_of_company_aquisition_ent(doc)
    aquisition_triples=get_aquisition_tuples(aquisition_triples,doc)
    product_triples=get_product_tuples(product_triples,doc)
    competitor_triples=get_competitor_triples(competitor_triples, doc)

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 146.43114590644836 seconds ---

# %%
print(num_aquisition_ent)
print(num_of_company_product_ent)
print(num_of_company_competitor_ent)
# Out:
# 1627
# 316
# 1564

# %%
print(competitor_triples)
# Out:
# [[['Atos Origin S.A.', 'ORG'], 'competitors', ['Fiserv', 'ORG']], [['Atos Origin S.A.', 'ORG'], 'competitors', ['SiNSYS', 'ORG']], [['Atos Origin S.A.', 'ORG'], 'competitors', ['VISA', 'ORG']], [['Atos Origin S.A.', 'ORG'], 'competitors', ['Mastercard', 'ORG']], [['NCR', 'ORG'], 'competitors', ['Ingenico Group', 'ORG']], [['NCR', 'ORG'], 'competitors', ['Adyen,', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['Fair Isaac Corporation', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['NCR', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['BAE Systems', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['FIS', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['Fiserv', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['SAS Institute, Inc.', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['Feedzai', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['Accertify', 'ORG']], [['NICE LTD', 'ORG'], 'competitors', ['American Express', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['NCR', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['Bottomline Technologies', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['Q2 Software, Inc.', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['Jack Henry & Associates, Inc.', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['FIS', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['Fiserv', 'ORG']], [['Digital Channels', 'ORG'], 'competitors', ['Finastra', 'ORG']], [['Bill Payment', 'ORG'], 'competitors', ['Fiserv', 'ORG']], [['Bill Payment', 'ORG'], 'competitors', ['FIS', 'ORG']], [['Bill Payment', 'ORG'], 'competitors', ['Jack Henry\xa0& Associates, Inc.', 'ORG']], [['Akamai', 'ORG'], 'compete', ['the Akamai Intelligent Edge Platform', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['LLC', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Resolution Products', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['LLC', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Avigilon Corporation', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Brivo Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Digital Monitoring Products Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Eagle Eye Networks Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Honeywell International Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Resideo Technologies Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Telular Corporation', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['AMETEK, Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['SecureNet Technologies, LLC', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['United Technologies Corporation', 'ORG']], [['ipDatatel', 'ORG'], 'competitors', ['Verkada Inc.', 'ORG']], [['Alarm.com', 'ORG'], 'compete', ['SimpliSafe', 'PRODUCT']], [['AT&T Inc.', 'ORG'], 'compete', ['Charter Communications, Inc.', 'ORG']], [['AT&T Inc.', 'ORG'], 'compete', ['Comcast', 'ORG']], [['AT&T Inc.', 'ORG'], 'compete', ["Google Inc.'s", 'ORG']], [['AT&T Inc.', 'ORG'], 'compete', ['Nest Labs, Inc.', 'ORG']], [['AT&T Inc.', 'ORG'], 'compete', ['Nest Secure', 'ORG']], [['AT&T Inc.', 'ORG'], 'compete', ['Nest', 'ORG']], [['Alarm.com', 'ORG'], 'competitors', ['Alarm.com', 'ORG']], [['Amazon.com', 'ORG'], 'compete', ['Amazon.com', 'ORG']], [['Intuit', 'ORG'], 'competitors', ['TurboTax', 'PRODUCT']], [['Intuit', 'ORG'], 'competitors', ['H&R Block’s', 'ORG']], [['Intuit', 'ORG'], 'competitors', ['DDIY', 'ORG']], [['Blucora', 'ORG'], 'competition', ['H&R Block', 'ORG']], [['Blucora', 'ORG'], 'competition', ['Liberty Tax', 'ORG']], [['Ellie Mae, Inc.', 'ORG'], 'compete', ['Sagent Lending Technologies', 'ORG']], [['Data and Analytics', 'ORG'], 'compete', ['CoreLogic, Inc.', 'ORG']], [['Data and Analytics', 'ORG'], 'compete', ['First American Financial Corporation', 'ORG']], [['Black Knight', 'ORG'], 'compete', ['CoreLogic, Inc.', 'ORG']], [['Black Knight', 'ORG'], 'compete', ['First American Financial Corporation', 'ORG']], [['Edmunds.com', 'ORG'], 'competitors', ['engine ...

# %%
print(product_triples)
# Out:
# [[['ACI Worldwide, Inc.', 'ORG'], 'products', ['ACI Worldwide', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'products', ['ACI Worldwide', 'ORG']], [['ACI', 'ORG'], 'provides', ['digital', 'ORG']], [['ACI', 'ORG'], 'provides', ['EBPP', 'ORG']], [['Postilion', 'ORG'], 'provides', ['ACI ReD Shield', 'ORG']], [['Postilion', 'ORG'], 'provides', ['ACI', 'ORG']], [['Postilion', 'ORG'], 'provides', ['Payments Gateway', 'ORG']], [['ACI ReD Shield', 'ORG'], 'provides', ['mCommerce', 'ORG']], [['ACI Worldwide', 'ORG'], 'products', ['ACI', 'ORG']], [['ACI Worldwide', 'ORG'], 'products', ['AOD', 'ORG']], [['ACI Worldwide', 'ORG'], 'products', ['ACI', 'ORG']], [['ACI Worldwide', 'ORG'], 'products', ['AOD', 'ORG']], [['Inc', 'ORG'], 'products', ['ACI', 'ORG']], [['Inc', 'ORG'], 'products', ['AOD', 'ORG']], [['ACI', 'ORG'], 'products', ['ACI', 'ORG']], [['ACI', 'ORG'], 'products', ['AOD', 'ORG']], [['ACI', 'ORG'], 'provide', ['ACI', 'ORG']], [['ACI Worldwide', 'ORG'], 'provide', ['ACI', 'ORG']], [['Inc', 'ORG'], 'provide', ['ACI', 'ORG']], [['ACI Worldwide', 'ORG'], 'services', ['Accenture', 'ORG']], [['ACI Worldwide', 'ORG'], 'services', ['LLC', 'ORG']], [['ACI Worldwide', 'ORG'], 'services', ['Cognizant Technology Solutions Corporation', 'ORG']], [['ACI Worldwide', 'ORG'], 'services', ['Stanchion Payments Solution', 'ORG']], [['ACI', 'ORG'], 'provide', ['ACI', 'ORG']], [['ACI Worldwide', 'ORG'], 'products', ['Inc', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['the Federal Financial Institutions Examination Council', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['FFIEC', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['the Federal Deposit Insurance Corporation', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['the Office of the Comptroller of the Currency', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['the Board of Governors', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['the Federal Reserve System', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'services', ['the National Credit Union Administration', 'ORG']], [['FFIEC', 'ORG'], 'serviced', ['ACI Worldwide', 'ORG']], [['FFIEC', 'ORG'], 'serviced', ['ACI Worldwide', 'ORG']], [['FFIEC', 'ORG'], 'serviced', ['Inc', 'ORG']], [['ACI', 'ORG'], 'designed', ['the U.S. Treasury', 'ORG']], [['ACI', 'ORG'], 'designed', ['Office of Foreign Assets Control', 'ORG']], [['ACI', 'ORG'], 'designed', ['OFAC', 'ORG']], [['ACI', 'ORG'], 'designed', ['the United Nations Security Council', 'ORG']], [['ACI', 'ORG'], 'designed', ['the European Union', 'ORG']], [['ACI', 'ORG'], 'Service', ['ACI', 'ORG']], [['ACI', 'ORG'], 'Service', ['Payments Risk Management', 'ORG']], [['LoyaltyOne', 'ORG'], 'products', ['Card Services', 'ORG']], [['FTC', 'ORG'], 'services', ['EU Directive', 'ORG']], [['FTC', 'ORG'], 'services', ['EC', 'ORG']], [['FTC', 'ORG'], 'services', ['EU', 'ORG']], [['Kona Site Defender', 'ORG'], 'service', ['DDoS', 'PRODUCT']], [['Kona Site Defender', 'ORG'], 'service', ['DDoS', 'PRODUCT']], [['Shield', 'PRODUCT'], 'designed', ['IP', 'ORG']], [['Akamai', 'ORG'], 'service', ['DNS', 'ORG']], [['Akamai', 'ORG'], 'service', ['DDoS', 'PRODUCT']], [['Routed', 'ORG'], 'designed', ['IP', 'ORG']], [['Routed', 'ORG'], 'designed', ['DDoS', 'PRODUCT']], [['iOS', 'ORG'], 'tools', ['Android', 'ORG']], [['Akamai', 'ORG'], 'offer', ['SPS', 'ORG']], [['DNS', 'ORG'], 'offer', ['DNS', 'ORG']], [['CDN', 'ORG'], 'designed', ['CDN', 'ORG']], [['CDN', 'ORG'], 'designed', ['Akamai', 'ORG']], [['CDN', 'ORG'], 'services', ['CDN', 'ORG']], [['AT&T', 'ORG'], 'sell', ['Deutsche Telecom', 'ORG']], [['AT&T', 'ORG'], 'sell', ['IBM', 'ORG']], [['AT&T', 'ORG'], 'sell', ['Microsoft', 'ORG']], [['AT&T', 'ORG'], 'sell', ['Orange Business Services', 'ORG']], [['AT&T', 'ORG'], 'sell', ['Telefonica Group', 'ORG']], [['Alarm.com', 'ORG'], 'Service', ['SaaS', 'ORG']], [['Software', 'ORG'], 'Service', ['SaaS', 'ORG']], [['Alarm.com', 'ORG'], 'service', ['SaaS', 'PRODUCT']], [['Amazon Echo', 'ORG'], 'devices', [ ...

# %%
print(aquisition_triples)
# Out:
# [[['Applied Communications Inc. Limited', 'ORG'], 'acquired', ['Tandem Computers Incorporated', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'acquired', ['Tandem Computers Incorporated', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'acquired', ['E Commerce Group Products, Inc.', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'acquired', ['The Western Union Company', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'acquired', ['Western Union', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'acquired', ['ECG', 'ORG']], [['ACI Worldwide, Inc', 'ORG'], 'acquired', ['Speedpay, Inc.', 'ORG']], [['Speedpay', 'ORG'], 'acquisition', ['ACI', 'ORG']], [['SaaS', 'ORG'], 'acquired', ['PaaS', 'ORG']], [['ACI', 'ORG'], 'acquired', ['ACI', 'ORG']], [['Saks', 'ORG'], 'acquired', ['ACI', 'ORG']], [['Shared Services', 'ORG'], 'acquired', ['ACI', 'ORG']], [['S1 Corporation', 'ORG'], 'acquired', ['ACI', 'ORG']], [['ACI', 'ORG'], 'acquired', ['Fidelity National Information Services Inc.', 'ORG']], [['Marketing and Product Management at Memento Inc.', 'ORG'], 'acquired', ['Fidelity National Information Services Inc.', 'ORG']], [['Akamai', 'ORG'], 'acquired', ['SSO', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['LLC', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Resolution Products', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['LLC', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Avigilon Corporation', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Brivo Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Digital Monitoring Products Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Eagle Eye Networks Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Honeywell International Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Resideo Technologies Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Telular Corporation', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['AMETEK, Inc.', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['SecureNet Technologies, LLC', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['United Technologies Corporation', 'ORG']], [['ipDatatel', 'ORG'], 'merger', ['Verkada Inc.', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['ObjectVideo, Inc.', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['ObjectVideo', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['ObjectVideo Labs', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['LLC', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['ObjectVideo Labs', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['Connect', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['Icontrol Networks, Inc.', 'ORG']], [['Alarm.com', 'ORG'], 'acquired', ['Icontrol', 'ORG']], [['1st Global', 'ORG'], 'acquisition', ['Wealth Management', 'ORG']], [['InfoSpace', 'ORG'], 'acquired', ['TaxAct', 'ORG']], [['InfoSpace', 'ORG'], 'acquisition', ['Blucora, Inc.', 'ORG']], [['Blucora', 'ORG'], 'acquired', ['Monoprice,', 'ORG']], [['Blucora', 'ORG'], 'acquired', ['HD Vest', 'ORG']], [['Blucora', 'ORG'], 'acquisition', ['1st Global, Inc.', 'ORG']], [['Blucora', 'ORG'], 'acquisition', ['Global Insurance Services,', 'ORG']], [['JRD', 'ORG'], 'acquire', ['HKFS', 'ORG']], [['LLC', 'ORG'], 'acquire', ['HKFS', 'ORG']], [['Blucora', 'ORG'], 'acquire', ['HKFS', 'ORG']], [['CarGurus', 'ORG'], 'acquisition', ['CarGurus', 'ORG']], [['Gannett', 'ORG'], 'acquired', ['Gannett', 'ORG']], [['Dealer Inspire Inc.', 'ORG'], 'acquired', ['Launch Digital Marketing LLC', 'ORG']], [['Government', 'ORG'], 'acquired', ['Express Scripts', 'ORG']], [['Government', 'ORG'], 'acquired', ['Medicare', 'ORG']], [['Government', 'ORG'], 'acquired', ['Medicaid', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Express Scripts', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Medicare', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Medicaid', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Express Scripts', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Medicare', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Medicaid', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Express Scripts', 'ORG']], [['Medicare', 'ORG'], 'acquired', ['Medicare', 'ORG']], [['Med ...

# %%
text=open(files[24])
#print(text.read())
#if \n Blablab \n if the first character is capitalized, add period
#if \n blablab \n if the first character is not capitalized, remove the first \n

# %%
doc = nlp(text.read())
options = {"ents": ["PERSON", "ORG", "PRODUCT"]}
#displacy.render(doc, style="ent", jupyter= True, options=options)

# %%
#find competitors
for sent in doc.sents:
    check=0
    relations = list()
    for token in sent:
        if token.lemma_ =="competitor" or token.lemma_ =="compete" or token.lemma_ =="competition":
                #entities_relation.append(token.text)
            if check==0 and len(sent.ents)>1: displacy.render(sent, style="ent", jupyter= True, options=options)
            relations.append(token.text)
            check=check+1
            #displacy.render(sent, style="dep", jupyter= True, options={"distance":140, "collapse_phrases":True})
    if len(relations)>0 and len(sent.ents)>1:print(relations)

# %%
#find products and services
for sent in doc.sents:
    check=0
    
    relations = list()
    for token in sent:
        
        if token.lemma_ =="product" or token.lemma_ =="service" or token.lemma_ =="sell" or token.lemma_=="device" or token.lemma_=="provide" or token.lemma_=="offer" or token.lemma_=="develop" or token.lemma_=="design" or token.lemma_=="solutions"or token.lemma_ =="manufacture" or token.lemma_ =="tool":
            if check==0 and len(sent.ents)>1: displacy.render(sent, style="ent", jupyter= True, options=options)
            relations.append(token.text)
            check=check+1
            
    if len(relations)>0 and len(sent.ents)>1:print(relations)
        
        
        
#get triples if the sentence do not contain compete and have entities that is not the company

# %%
#find m&a activities
for sent in doc.sents:
    check=0
    relations = list()
    for token in sent:
        if token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
            if check==0 and len(sent.ents)>1: displacy.render(sent, style="ent", jupyter= True, options=options)
            relations.append(token.text)
            check=check+1
            
    if len(relations)>0 and len(sent.ents)>1:print(relations)
        
#get triples if there are more than 1 entities and one of the entities is the company, the rest is not the company

# %%
#products triples

for sent in doc.sents:
    #get relations
    relations = list()
    ents=list()
    head=list()
    tail=list()
    check=True
    has_other_relation=False
    for token in sent:
        if token.lemma_ =="competitor" or token.lemma_ =="compete" or token.lemma_ =="competition" or token.lemma_=="client" or token.lemma_=="manufacturer" or token.lemma_=="customer" or token.lemma_=="buyer" or token.lemma_=="purchase" or token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
            has_other_relation=True
    if has_other_relation==False:
        for i, token in enumerate(sent):
            if token.lemma_ =="product" or token.lemma_ =="service" or token.lemma_ =="sell" or token.lemma_=="device" or token.lemma_=="provide" or token.lemma_=="offer" or token.lemma_=="develop" or token.lemma_=="design" or token.lemma_=="solutions"or token.lemma_ =="manufacture" or token.lemma_ =="tool":
                relations.append(token.text)
                if check==True:
                    for ent in sent[:i].ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            if ent.text not in head and ent.text not in tail:
                                head.append(ent.text)
                    for ent in sent[i:].ents:
                        if ent.label_=='ORG' or ent.label_=='PRODUCT':
                            if ent.text not in tail and ent.text not in head:
                                tail.append(ent.text)
                    check= False
                    if len(head)==0 and len(tail)>1:
                        head.append(tail[0])
                        tail.pop(0)
    if len(relations)>0  and len(head)>0 and len(tail)>0:

        #print(head )
        #print(relations)
        #print(tail)
        #print()
        for h in head:
            for t in tail:
                triples.append([h, relations[0], t])
print(triples)

# %%
#acquisition triples
triples=list()
for sent in doc.sents:
    #get relations
    relations = list()
    ents=list()
    head=list()
    tail=list()
    check=True
    has_other_relation=False

    for i, token in enumerate(sent):
        if token.lemma_=="acquisition" or token.lemma_=="acquire" or token.lemma_=="merger" or token.lemma_=="merge" or token.lemma_=="consolidate" or token.lemma_=="consolidation":
            relations.append(token.text)
            if check==True:
                for ent in sent[:i].ents:
                    if ent.label_=='ORG' or ent.label_=='PRODUCT' or ent.label_=='PERSON':
                        if ent.text not in head and ent.text not in tail:
                            head.append(ent.text)
                for ent in sent[i:].ents:
                    if ent.label_=='ORG' or ent.label_=='PRODUCT':
                        if ent.text not in tail and ent.text not in head:
                            tail.append(ent.text)
                check= False
                if len(head)==0 and len(tail)>1:
                    head.append(tail[0])
                    tail.pop(0)
    if len(relations)>0  and len(head)>0 and len(tail)>0:

        #print(head )
        #print(relations)
        #print(tail)
        #print()
        for h in head:
            for t in tail:
                triples.append([h, relations[0], t])
print(triples)

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_kg(pairs):
    k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
    node_deg = nx.degree(k_graph)
    layout = nx.spring_layout(k_graph, k=0.15, iterations=20)
    plt.figure(num=None, figsize=(120, 90), dpi=80)
    nx.draw_networkx(
        k_graph,
        node_size=[int(deg[1]) * 500 for deg in node_deg],
        arrowsize=20,
        linewidths=1.5,
        pos=layout,
        edge_color='red',
        edgecolors='black',
        node_color='white',
        )
    labels = dict(zip(list(zip(pairs.subject, pairs.object)),
                  pairs['relation'].tolist()))
    nx.draw_networkx_edge_labels(k_graph, pos=layout, edge_labels=labels,
                                 font_color='red')
    plt.axis('off')
    plt.show()

def filter_graph(pairs, node):
    k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
    edges = nx.dfs_successors(k_graph, node)
    nodes = []
    for k, v in edges.items():
        nodes.extend([k])
        nodes.extend(v)
    subgraph = k_graph.subgraph(nodes)
    layout = (nx.random_layout(k_graph))
    nx.draw_networkx(
        subgraph,
        node_size=1000,
        arrowsize=20,
        linewidths=1.5,
        pos=layout,
        edge_color='red',
        edgecolors='black',
        node_color='white'
        )
    labels = dict(zip((list(zip(pairs.subject, pairs.object))),
                    pairs['relation'].tolist()))
    edges= tuple(subgraph.out_edges(data=False))
    sublabels ={k: labels[k] for k in edges}
    #print(k_graph.out_edges(data=False))
    nx.draw_networkx_edge_labels(subgraph, pos=layout, edge_labels=sublabels,
                                font_color='red')
    plt.axis('off')
    plt.show()

# %%
import pandas as pd
pairs = pd.DataFrame(triples, columns=['subject',
                         'relation', 'object'])
draw_kg(pairs)

# %%
from spacy.pipeline import EntityRuler

nlp = spacy.load('en_core_web_lg')
ruler = EntityRuler(nlp)
pattern_windows = [
    {"label": "PRODUCT", "pattern": [{"TEXT": "Skype"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "OneDrive"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Outlook"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "windows"}, {'IS_DIGIT': True, 'OP': '?'}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Office"}, {'IS_DIGIT': True, 'OP': '?'}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Xbox"}, {'TEXT': "Live", 'OP': '?'}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Visual"}, {'TEXT': "Studio"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Studios"}, {'IS_DIGIT': True, 'OP': '?'}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Surface"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Dynamics"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "LinkedIn"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "Bing"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "MSN"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "Azure"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "Lumia"}]},
    
]
pattern_appl = [
    {"label": "PRODUCT", "pattern": [{"TEXT": "App"},{"IS_PUNCT": True},{"TEXT":"Store"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "iTunes"},{"IS_PUNCT": True},{"TEXT":"Store"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Apple"},{"IS_PUNCT": True},{"POS":"NOUN"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "Mac"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "iPod"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "iBooks"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "iCloud"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "iPhone"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "watchOS"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "macOS"}]},
    {"label": "PRODUCT", "pattern": [{"TEXT": "iOS"}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "AirPods"}]}
]
ruler.add_patterns(pattern_appl)
ruler.add_patterns(pattern_windows)

nlp.add_pipe(ruler,before="ner")

# %%
from spacy.matcher import Matcher
#train NER model

#create training data
matcher = Matcher(nlp.vocab)
pattern_windows = [
    {[{"LOWER": "Skype"}]},
    {[{"LOWER": "OneDrive"}]},
    {[{"TEXT": "Outlook"}]},
    {[{"LOWER": "windows"}, {'IS_DIGIT': True, 'OP': '?'}]},
    {[{"LOWER": "Office"}, {'IS_DIGIT': True, 'OP': '?'}]},
    {[{"LOWER": "Xbox"}, {'TEXT': "Live", 'OP': '?'}]},
    {{"TEXT": "Visual"}, {'TEXT': "Studio"}]},
    {[{"TEXT": "Studios"}, {'IS_DIGIT': True, 'OP': '?'}]},
    {[{"LOWER": "Xbox"}, {'TEXT': "Live", 'OP': '?'}]},
    {[{"TEXT": "Surface"}]},
    {[{"TEXT": "Dynamics"}]},
    {[{"LOWER": "LinkedIn"}]},
]
pattern_appl = [
    {[{"TEXT": "App"},{"TEXT":"Store"}]},
    {[{"LOWER": "iTunes"},{"TEXT":"Store"}]},
    {[{"TEXT": "Apple"},{"POS":"NOUN"}]},
    {[{"LOWER": "Mac"}]},
    {[{"LOWER": "iPod"}]},
    {[{"LOWER": "iBooks"}]},
    {[{"LOWER": "iCloud"}]},
    {[{"LOWER": "iPhone"}]},
    {[{"LOWER": "watchOS"}]},
    {[{"LOWER": "macOS"}]},
    {[{"LOWER": "iOS"}]},
]
TRAINING_DATA = []

# Create a Doc object for each text in TEXTS
for sent in nlp.pipe(doc):
    # Match on the doc and create a list of matched spans
    spans = [sent[start:end] for match_id, start, end in matcher(sent)]
    # Get (start character, end character, label) tuples of matches
    entities = [(span.start_char, span.end_char, "PRODUCT") for span in spans]
    # Format the matches as a (doc.text, entities) tuple
    training_example = (sent.text, {"entities": entities})
    # Append the example to the training data
    TRAINING_DATA.append(training_example)

print(*TRAINING_DATA, sep="\n")


#train the model https://spacy.io/usage/training#ner

# %%
"""
# Patterns are lists of dictionaries describing the tokens


#use matcher to get entities
matcher.add("PRODUCT", None, pattern_windows, pattern_appl)
def extra_ent_component(doc):
    # Create an entity Span with the label "GPE" for all matches
    matches = matcher(doc)
    doc.ents = [Span(doc, start, end, label="PRODUCT") for match_id, start, end in matches]
    return doc

#print entities NER
entity_pairs = []
for sent in doc.sents:
    if sent.ents and (e.label_=="ORG" or e.label_=="PERSON" or e.label_=="PRODUCT" for e in doc.ents):
        #entity_pairs.append([sent.ents[0],sent.ents[1]])
        print(sent)
        print(sent.ents)
        #print("["+sent.ents[0].text+", "+sent.root.text+", "+sent.ents[1].text+"]" )
        print()
    #if ent.label_=='ORG' or ent.label_=='PRODUCT' or ent.label_=='PERSON':
        #print(ent.text, ent.start_char, ent.end_char, ent.label_)

#get verbs from every sentences dep_ as relations
entities_relation = []
for sent in doc.sents:
        for token in sent:
            if token.pos_=="VERB" or token.pos_=="AUX":
                #entities_relation.append(token.text)
                print(sent)
                print("["+token.text+"]")
                print()
"""

# %%
#try to find sector
for sent in doc.sents:
    check=0
    relations = list()
    for token in sent:
        if token.lemma_ =="industry" or token.lemma_ =="sector" or token.lemma_ =="leader" or token.lemma_ =="lead":
            if check==0 : displacy.render(sent, style="ent", jupyter= True, options=options)
            relations.append(token.text)
            check=check+1
    if len(relations)>0:print(relations)
            #displacy.render(sent, style="dep", jupyter= True, options={"distance":140, "collapse_phrases":True})

# %%
#find customer
for sent in doc.sents:
    check=0
    relations = list()
    for token in sent:
        if  token.lemma_=="client" or token.lemma_=="manufacturer" or token.lemma_=="customer" or token.lemma_=="buyer" or token.lemma_=="purchase":
            if check==0 and len(sent.ents)>1: displacy.render(sent, style="ent", jupyter= True, options=options)
            relations.append(token.text)
            check=check+1
    if len(relations)>0 and len(sent.ents)>1:print(relations)
